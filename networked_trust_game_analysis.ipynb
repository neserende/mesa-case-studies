# %% [markdown]
# ## Networked Trust Game of Investors and Investees
#
# This is the implementation of the paper "xxx" on Mesa.

# %%
# import matplotlib.pyplot as plt
from model import TrustGameModel, State

# %matplotlib inline

# %% [markdown]
# #### Helper functions

# %%
# from mesa.visualization.mpl_space_drawing import draw_space

# def agent_portroyal(agent):
#     node_color_dict = {
#         0: "blue",
#         1: "green",
#         2: "yellow",
#     }
#     return {"color": node_color_dict[agent.state.value], "size": 10}

# %%
import time
def run_model(model):
    """
    Run an experiment with a given model, and plot the results.
    """
    # draw_space(model.grid, agent_portroyal)
    start = time.time()
    model.run(5000)
    end = time.time()
    print("Total time to run the simulation: ", end-start, " seconds")
    # model.datacollector.get_model_vars_dataframe().plot()

# %%
# # Set the random seed
# seed = 21

# %%
tg_model = TrustGameModel()
run_model(tg_model)
# Out:
# Total time to run the simulation:  598.6923797130585  seconds

# %%
# def network_state_saver(graph, step):
#     pass

# %%
print(tg_model.datacollector.get_model_vars_dataframe())
# Out:
#      I    T    U  global_payoff
# 0  307  256  461         0.0000
# 1  141  479  404      1329.3843

# %%
# draw_space(tg_model.grid, agent_portroyal)
# Out:
# <Axes: >
